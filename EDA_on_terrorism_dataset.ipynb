# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradhiksha05/EDA-on-Terrorism-dataset/blob/main/EDA_on_terrorism_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Terror=pd.read_csv('/content/globalterrorismdb_0718dist.csv', on_bad_lines='skip' , encoding='latin')
pd.set_option("display.max_columns",500)
# Out:
# <ipython-input-4-b206876e3e52>:1: DtypeWarning: Columns (4,31,33,62,76,79,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   Terror=pd.read_csv('/content/globalterrorismdb_0718dist.csv', on_bad_lines='skip' , encoding='latin')

# %%
Terror.shape
# Out:
# (18870, 135)

# %%
Terror.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
Terror.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
Terror.tail()
# Out:
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 18865  198305240006   1983       5    24        NaN         0        NaN
# 18866  198305240007   1983       5    24        NaN         0        NaN
# 18867  198305240008   1983       5    24        NaN         0        NaN
# 18868  198305240009   1983       5    24        NaN         0        NaN
# 18869  198305240010   1983       5    24        NaN         0        NaN
#
#        country     country_txt  region                   region_txt  \
# 18865       45        Colombia       3                South America
# 18866       45        Colombia       3                South America
# 18867      145       Nicaragua       2  Central America & Caribbean
# 18868      145       Nicaragua       2  Central America & Caribbean
# 18869      603  United Kingdom       8               Western Europe
#
#               provstate             city   latitude  longitude  specificity  \
# ...

# %%
Terror.info
# Out:
# <bound method DataFrame.info of             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0      197000000001   1970       7     2        NaN         0        NaN
# 1      197000000002   1970       0     0        NaN         0        NaN
# 2      197001000001   1970       1     0        NaN         0        NaN
# 3      197001000002   1970       1     0        NaN         0        NaN
# 4      197001000003   1970       1     0        NaN         0        NaN
# ...             ...    ...     ...   ...        ...       ...        ...
# 18865  198305240006   1983       5    24        NaN         0        NaN
# 18866  198305240007   1983       5    24        NaN         0        NaN
# 18867  198305240008   1983       5    24        NaN         0        NaN
# 18868  198305240009   1983       5    24        NaN         0        NaN
# 18869  198305240010   1983       5    24        NaN         0        NaN
#
# ...

# %%
Terror.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  1.887000e+04  18870.000000  18870.000000  18870.000000  18870.000000
# mean   1.978580e+11   1978.517011      6.198781     15.206465      0.019131
# std    3.406406e+08      3.409654      3.448318      8.955007      0.136989
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.977042e+11   1977.000000      3.000000      8.000000      0.000000
# 50%    1.979101e+11   1979.000000      6.000000     15.000000      0.000000
# 75%    1.981082e+11   1981.000000      9.000000     23.000000      0.000000
# max    1.983052e+11   1986.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  18870.000000  18870.000000  18123.000000  1.812300e+04  18870.000000
# mean     177.541176      5.416428     26.370738 -4.786345e+03      1.289401
# ...

# %%
Terror.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    18849
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       18143
# Length: 135, dtype: int64

# %%
Terror.dropna(inplace=True)

# %%
Terror.isnull().sum()
# Out:
# eventid       0.0
# iyear         0.0
# imonth        0.0
# iday          0.0
# approxdate    0.0
#              ...
# INT_LOG       0.0
# INT_IDEO      0.0
# INT_MISC      0.0
# INT_ANY       0.0
# related       0.0
# Length: 135, dtype: float64

# %%
Terror.duplicated()
# Out:
# Series([], dtype: bool)
